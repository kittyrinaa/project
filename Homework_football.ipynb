# %% [markdown]
# ### Step 1. Import the necessary libraries (pandas)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from Teams (US_Crime_Rates_1960_2014.csv)

# %%
df = pd.read_csv('Euro_2012_stats_TEAM.csv')

# %% [markdown]
# ### Visualize with a pie chart the ratio of countries to the number of withdrawals

# %%
df.tail(20)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Which Teams got red cards?

# %%
red_cards = df[df['Red Cards'] > 0]['Team']
print(red_cards)
# Out:
# 6                  Greece
# 9                  Poland
# 11    Republic of Ireland
# Name: Team, dtype: object

# %% [markdown]
# ### Hystogram of completed passes

# %%
    team_names = df["Team"]
    passes_count = df["Passes completed"]
 
    # Creating a bar plot with different colors for each team
    plt.bar(team_names, passes_count, color=["red", "blue", "green", "yellow", "orange"]
            )
 
    # Adding labels and title to the plot
    plt.xlabel("Team Name")
    plt.ylabel("Passes Count")
    plt.title("Histogram of Passes for Each Team")
 
    # Displaying the plot
    plt.show()

# %% [markdown]
# ### Pie chart of goals

# %%
plt.pie(df["Goals"], labels = df["Team"])
plt.show()
